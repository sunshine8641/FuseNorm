# %%
import os

# 切换到上层文件夹
os.chdir("..")

# 验证
print("当前工作目录:", os.getcwd())
# Out:
# 当前工作目录: /Users/sunshine8641/Code/OOD

# %%
import os
import torch
import torch.nn as nn
from accelerate import Accelerator
from data_utils.build_dataset import build_id_dataloaders,build_ood_dataloaders,build_jigsaw_dataloaders
from methods import forward_base,calculate_layer_norm
from models import get_model,ParametricBReLU,ParametricBoundedLeakyReLU,BoundedPReLU
from utils import get_args, merge_args_with_config, load_config, accuracy, MetersGroup,\
format_meters_log
from safetensors.torch import load_file
from collections import OrderedDict
# from methods import get_forward,get_score,compute_activation_stats,get_all_scores,\
#                     compute_threshold_react,calculate_layer_norm,get_all_scores,
from metrics import  *
# from methods import compute_threshold_react
from  methods import *
import seaborn as sns
from scipy.stats import norm

import matplotlib.pyplot as plt
from train.train_utils import load_clean_model_state
from eval import exp_base,  initialize_experiment
from data_utils.transforms import get_ood_transform,get_id_transform


from utils import *

# %%
args = argparse.Namespace()
args.config="configs/vaod_imagenet_resnet.yaml"# get_args()

if args.config:
    cfg = load_config(args.config)
    config = merge_args_with_config(args, cfg)
else:
    config = vars(args)  # 如果没有配置文件，直接用args
print(config)
# Out:
# {'exp_name': 'resnet18_imagenet_pleaky', 'id_dataset': {'name': 'imagenet', 'root': '/Users/sunshine8641/Code/Data/'}, 'ood_dataset': {'name': 'svhn', 'root': '/Users/sunshine8641/Code/Data/'}, 'top_5': False, 'model': {'type': 'resnet18', 'pretrained': False, 'num_classes': 100, 'activation': 'BoundedPReLU', 'last_block_activation': 'BoundedPReLU'}, 'num_classes': 100, 'test_model': 'base_best', 'start_epoch': 0, 'epochs': 200, 'lr': 0.1, 'min_lr': 0, 'weight_decay': 5e-05, 'mixed_precision': 'fp16', 'batch_size': 128, 'num_workers': 4, 'momentum': 0.9, 'optimizer': 'SGD', 'scheduler': 'cosine', 'step_gamma': 0.1, 'step_size': 30, 'train_method': 'base', 'use_swa': False, 'swa_window': 40, 'swa_start': 0, 'label_smooth': True, 'smoothing': 0.1, 'teacher': {'type': 'resnet34_cifar', 'pretrained': False, 'num_classes': 100}, 'teacher_path': 'resnet34_base.pt', 'distill_alpha': 0.5, 'distill_temperature': 4.0, 'log': {'log_dir': './logs', 'use_loguru': True}, 'odin_temperature': 1000.0, 'odin_magnitude': 0.01, 'bats_lam': 3.25, 'laps_lam': 1.5, 'laps_m': 13, 'laps_n': 0, 'num_blocks': 8, 'sblock': 0, 'energy_k': 10, 'config': 'configs/vaod_imagenet_resnet.yaml'}

# %%
accelerator,model,criterion,train_meters,test_meters,top_k,id_train_loader,id_test_loader,id_val_loader,ood_loader=initialize_experiment(config)
# Out:
# [Test] Loading OOD Dataloader for svhn...
# mps

# %% [markdown]
# <h1 style="color:green; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   Prepare Experiment
# </h1>

# %%
tr=get_id_transform(cfg['id_dataset']['name'])
for t in tr[0].transforms:
    if isinstance(t, transforms.Normalize):
        print("Mean:", t.mean)
        mean=t.mean
        print("Std:", t.std)
        std=t.std
# Out:
# Mean: [0.485, 0.456, 0.406]
# Std: [0.229, 0.224, 0.225]

# %% [markdown]
# <h1 style="color:blue; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   ID DATA SAMPLE
# </h1>

# %%
for batch in id_val_loader:
    x, y = batch
    print(f"ID Train Batch: x.shape={x.shape}, y.shape={y.shape}")
    break
show_images(x, y,mean,std, n=4)
# Out:
# ID Train Batch: x.shape=torch.Size([128, 3, 224, 224]), y.shape=torch.Size([128])

# %%
model.eval()
test_meters.reset()
with torch.no_grad():
    for inputs, targets in id_test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        topk_acc = accuracy(outputs, targets, topk=top_k)
        acc_dict = {f"Acc@{k}": acc.item() for k, acc in zip(top_k, topk_acc)}
        acc_dict["Loss"] = loss.item()
        test_meters.update(acc_dict, n=targets.size(0))
log_str = format_meters_log(0, test_meters.meters,0, None, prefix="Val Epoch")
print(log_str)
# Out:
# Val Epoch 0 | Loss: 0.8623 | Acc@1: 81.31% | Time: 0.00

# %% [markdown]
# <h1 style="color:blue; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   compute_id_statistics
# </h1>

# %%
scores_in_allv=[]
for i in range(0,8):
    config["sblock"]=i
    forward_func = get_forward(name="forward_features", config=config)
    method="featurenorm"
    n_iter=55
    scores_in_all_i=get_all_scores( model,id_val_loader, forward_func,method, config, n_iter,accelerator)
    scores_in_allv.append(scores_in_all_i)
means, stds=compute_id_statistics(scores_in_allv)
print(means.shape)
print(stds.shape)
plot_histograms_one(scores_in_allv,means,stds, bins=50, title="Histograms of OOD Scores")
# Out:
# (8,)
# (8,)

# %%
stds
# Out:
# array([2.888899  , 2.9661765 , 0.9389373 , 1.1844772 , 0.3880762 ,
#        0.39753664, 0.09163599, 0.7820022 ], dtype=float32)

# %% [markdown]
# <h1 style="color:green; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   OOD Dataset1: Textures
# </h1>

# %%
cfg["ood_dataset"]["name"]="textures"
accelerator,model,criterion,train_meters,test_meters,top_k,id_train_loader,id_test_loader,id_val_loader,ood_loader=initialize_experiment(config)
for batch in ood_loader:
    x, y = batch
    print(f"ID Train Batch: x.shape={x.shape}")
    break
show_images(x, y,mean,std, n=4)
# Out:
# [Test] Loading OOD Dataloader for textures...
# mps
# ID Train Batch: x.shape=torch.Size([128, 3, 224, 224])

# %%
scores_in_all1=[]
scores_out_all1=[]
for i in range(0,8):
    config["sblock"]=i
    forward_func = get_forward(name="forward_features", config=config)
    method="featurenorm"
    n_iter=55
    scores_in_all_i=get_all_scores( model,id_test_loader, forward_func,method, config, n_iter,accelerator)
    scores_out_all_i=get_all_scores( model,ood_loader, forward_func,method, config, n_iter,accelerator)
    scores_in_all1.append(scores_in_all_i)
    scores_out_all1.append(scores_out_all_i)
plot_histograms(scores_in_all1, scores_out_all1, bins=50, title="Histograms of OOD Scores")

# %%
scores_in_all_standard_texture=compute_standard_score(scores_in_all1, means, stds)
scores_out_all_standard_texture=compute_standard_score(scores_out_all1, means, stds)
i1=get_vaod_score(scores_in_all_standard_texture)
o1=get_vaod_score(scores_out_all_standard_texture)
plot_histograms([i1], [o1], bins=50, title="Histograms of OOD Scores")

# %% [markdown]
# <h1 style="color:green; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   OOD Dataset2: INaturalist
# </h1>

# %%
cfg["ood_dataset"]["name"]="iNaturalist"
accelerator,model,criterion,train_meters,test_meters,top_k,id_train_loader,id_test_loader,id_val_loader,ood_loader=initialize_experiment(config)
for batch in ood_loader:
    x, y = batch
    print(f"ID Train Batch: x.shape={x.shape}")
    break
show_images(x, y,mean,std, n=4)
# Out:
# [Test] Loading OOD Dataloader for iNaturalist...
# /Users/sunshine8641/Code/Data/iNaturalist
# mps
# ID Train Batch: x.shape=torch.Size([128, 3, 224, 224])

# %%
scores_in_all2=[]
scores_out_all2=[]
for i in range(0,8):
    config["sblock"]=i
    forward_func = get_forward(name="forward_features", config=config)
    method="featurenorm"
    n_iter=55
    scores_in_all_i=get_all_scores( model,id_test_loader, forward_func,method, config, n_iter,accelerator)
    scores_out_all_i=get_all_scores( model,ood_loader, forward_func,method, config, n_iter,accelerator)
    scores_in_all2.append(scores_in_all_i)
    scores_out_all2.append(scores_out_all_i)
plot_histograms(scores_in_all2, scores_out_all2, bins=50, title="Histograms of OOD Scores")

# %%
scores_in_all_standard_inaturalist=compute_standard_score(scores_in_all2, means, stds)
scores_out_all_standard_inaturalist=compute_standard_score(scores_out_all2, means, stds)
i1=get_vaod_score(scores_in_all_standard_inaturalist)
o1=get_vaod_score(scores_out_all_standard_inaturalist)
plot_histograms([i1], [o1], bins=50, title="Histograms of OOD Scores")

# %% [markdown]
# <h1 style="color:green; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   OOD Dataset3: SUN
# </h1>

# %%
cfg["ood_dataset"]["name"]="SUN"
accelerator,model,criterion,train_meters,test_meters,top_k,id_train_loader,id_test_loader,id_val_loader,ood_loader=initialize_experiment(config)
for batch in ood_loader:
    x, y = batch
    print(f"ID Train Batch: x.shape={x.shape}")
    break
show_images(x, y,mean,std, n=4)
# Out:
# [Test] Loading OOD Dataloader for SUN...
# /Users/sunshine8641/Code/Data/SUN
# mps
# ID Train Batch: x.shape=torch.Size([128, 3, 224, 224])

# %%
scores_in_all3=[]
scores_out_all3=[]
for i in range(0,8):
    config["sblock"]=i
    forward_func = get_forward(name="forward_features", config=config)
    method="featurenorm"
    n_iter=55
    scores_in_all_i=get_all_scores( model,id_test_loader, forward_func,method, config, n_iter,accelerator)
    scores_out_all_i=get_all_scores( model,ood_loader, forward_func,method, config, n_iter,accelerator)
    scores_in_all3.append(scores_in_all_i)
    scores_out_all3.append(scores_out_all_i)
plot_histograms(scores_in_all3, scores_out_all3, bins=50, title="Histograms of OOD Scores")

# %%
scores_in_all_standard_sun=compute_standard_score(scores_in_all3, means, stds)
scores_out_all_standard_sun=compute_standard_score(scores_out_all3, means, stds)
i1=get_vaod_score(scores_in_all_standard_sun)
o1=get_vaod_score(scores_out_all_standard_sun)
plot_histograms([i1], [o1], bins=50, title="Histograms of OOD Scores")

# %% [markdown]
# <h1 style="color:green; text-shadow: 0 0 10px #ff00ff, 0 0 10px #ff00ff">
#   OOD Dataset4: PLACES
# </h1>

# %%
cfg["ood_dataset"]["name"]="Places"
accelerator,model,criterion,train_meters,test_meters,top_k,id_train_loader,id_test_loader,id_val_loader,ood_loader=initialize_experiment(config)
for batch in ood_loader:
    x, y = batch
    print(f"ID Train Batch: x.shape={x.shape}")
    break
show_images(x, y,mean,std, n=4)
# Out:
# [Test] Loading OOD Dataloader for Places...
# /Users/sunshine8641/Code/Data/Places
# mps
# ID Train Batch: x.shape=torch.Size([128, 3, 224, 224])

# %%
scores_in_all4=[]
scores_out_all4=[]
for i in range(0,8):
    config["sblock"]=i
    forward_func = get_forward(name="forward_features", config=config)
    method="featurenorm"
    n_iter=55
    scores_in_all_i=get_all_scores( model,id_test_loader, forward_func,method, config, n_iter,accelerator)
    scores_out_all_i=get_all_scores( model,ood_loader, forward_func,method, config, n_iter,accelerator)
    scores_in_all4.append(scores_in_all_i)
    scores_out_all4.append(scores_out_all_i)
plot_histograms(scores_in_all4, scores_out_all4, bins=50, title="Histograms of OOD Scores")

# %%
scores_in_all_standard_places=compute_standard_score(scores_in_all4, means, stds)
scores_out_all_standard_places=compute_standard_score(scores_out_all4, means, stds)
i1=get_vaod_score(scores_in_all_standard_places)
o1=get_vaod_score(scores_out_all_standard_places)
plot_histograms([i1], [o1], bins=50, title="Histograms of OOD Scores")
